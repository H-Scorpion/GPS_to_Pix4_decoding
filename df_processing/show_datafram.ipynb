# %%
import plotly.express as px
import pandas as pd

df = pd.read_pickle('ubxPacket_20210901-165743_df.pkl')

# %%
fig = px.scatter(
    # df[df['__name__'] == 'PVT'],
    df,
    x='timestamp',
    y='__name__'


)

# fig.update_traces(
#     mode='markers+lines'
# )

fig.show()

# %%
print(df.loc[0])
df.loc[0, 'week'] = 0
df.loc[0]['obj'].week = 0
# print(df.loc[0])

print(df.loc[0]['obj'])
# Out:
# iTOW      291481000.0
# fTOW        -273561.0
# week              0.0
# gpsFix            3.0
# flags           221.0
#              ...
# VP                NaN
# jamInd            NaN
# pinIrq            NaN
# pullH             NaN
# pullL             NaN
# Name: 0, Length: 69, dtype: object
# NAV-SOL:
#   iTOW=0x115FA5A8
#   fTOW=0x-0042C99
#   week=0x0000
#   gpsFix=0x03
#   flags=0xDD
#   ecefX=0x-12066ACF
#   ecefY=0x1D624C53
#   ecefZ=0x0FF9E76A
#   pAcc=0x00000208
#   ecefVX=0x-0000003
#   ecefVY=0x-0000016
#   ecefVZ=0x00000006
#   sAcc=0x0000004F
#   pDOP=0x01BA
#   reserved1=0x02
#   numSV=0x08
#   reserved2=0x00034AF8

# %%
# print(df['__name__'] == 'PVT')
mask = df['__name__'] == 'PVT'
print(mask)
print(df[mask].index)

# print(df.loc[0:2, ['__name__', 'sAcc']])
# print(df.iloc[0:2, 3])
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 5018     True
# 5019    False
# 5020    False
# 5021     True
# 5022    False
# Name: __name__, Length: 5023, dtype: bool
# Int64Index([   1,    4,    7,   10,   13,   16,   20,   23,   26,   29,
#             ...
#             4994, 4997, 5000, 5003, 5006, 5009, 5012, 5015, 5018, 5021],
#            dtype='int64', length=1652)
